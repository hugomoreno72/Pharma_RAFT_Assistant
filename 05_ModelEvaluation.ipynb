# %%
# %%capture

# !pip install torch==2.4.1 torchvision==0.19.1 torchaudio==2.4.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install transformers accelerate peft trl bitsandbytes
# !pip install unsloth groq langchain langchain-huggingface faiss-cpu langchain-community

# %%
import os
from google.colab import userdata

# %%
os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

# %%
from unsloth import FastLanguageModel
import torch
from unsloth.chat_templates import get_chat_template
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
from groq import Groq
import json
import random
import time
client = Groq(api_key=os.environ.get("GROQ_API_KEY"),)

# %%
# Load Gemma-3 Base
base_model, base_tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-3-4b-it",
    max_seq_length = 2048,
    load_in_4bit = True,
    dtype= None
)
base_tokenizer = get_chat_template(base_tokenizer, chat_template="gemma-3")

# %%
# Load my model
import shutil
# I unzip the zip file containing the model
shutil.unpack_archive("lora_pharma.zip", "lora_pharma", "zip")

# %%
my_model, my_tokenizer = FastLanguageModel.from_pretrained(
    model_name = "lora_pharma",
    max_seq_length = 2048,
    load_in_4bit = True,
)

# %%
FastLanguageModel.for_inference(my_model)
FastLanguageModel.for_inference(base_model)

# %%
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings


embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vector_db = FAISS.load_local("faiss_pharmacy", embeddings, allow_dangerous_deserialization=True)

# %%
def generate_questions(n_questions):
    """Generates questions retrieved from a FAISS vector database using Llama-3.3-70B"""

    final_questions = []
    docstore = vector_db.docstore._dict
    all_ids = list(docstore.keys())

    print(f"\n📚 Generating {n_questions} questions\n")

    for i in range(n_questions):
        try:
            random_id = random.choice(all_ids)
            real_text = docstore[random_id].page_content

            prompt = f"""You are a pharmacology expert. Generate ONE evaluation question about pharmacology based on this snippet from the database.

SNIPPET:
{real_text}

Include:
1. context: Relevant medical information (2-3 sentences)
2. question: A specific question
3. key_points: List of points that the correct answer must include

Respond ONLY in valid JSON format with these exact keys:
{{
  "question": "What is the mechanism of action of..?",
  "context": "Brief context here",
  "key_points": ["point 1", "point 2", "point 3"]
}}

Do NOT include markdown code blocks, just raw JSON."""

            response = client.chat.completions.create(
                model="llama-3.3-70b-versatile",
                messages=[{"role": "user", "content": prompt}],
                response_format={"type": "json_object"},
                temperature=0.1,
                max_tokens=2000,
            )

            content = response.choices[0].message.content

            # Clean possible markdowns
            content = content.replace('```json', '').replace('```', '').strip()

            question_json = json.loads(content)

            final_questions.append(question_json)
            q_text = question_json.get('question', 'No question generated')
            print(f"Question {i+1}: {q_text[:120]}...")

    print(f"\nSuccessfully generated {len(final_questions)} questions\n")
    return final_questions

# %%
def base_model_response(question, context):
    """Generates response from Model A (Base)"""

    messages = [{"role": "user", "content": f"Context: {context}\n\nQuestion: {question}"}]

    prompt = base_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = base_tokenizer(text=prompt, return_tensors="pt", padding=True)
    inputs = {k: v.to("cuda") for k, v in inputs.items()}

    outputs = base_model.generate(**inputs, max_new_tokens=400, temperature=0.1)

    response = base_tokenizer.tokenizer.batch_decode(outputs)[0]
    # Extracting the model's turn from the chat template
    answer = response.split("<start_of_turn>model ")[-1].replace("<end_of_turn>", "").strip()

    del inputs, outputs
    torch.cuda.empty_cache()

    return answer

# %%
def my_model_response(question, context):
    """Generates response from Model B (Your fine-tuned model)"""

    messages = [{"role": "user", "content": f"Context: {context}\n\nQuestion: {question}"}]

    prompt = my_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    inputs = my_tokenizer(text=prompt, return_tensors="pt", padding=True)
    inputs = {k: v.to("cuda") for k, v in inputs.items()}

    outputs = my_model.generate(**inputs, max_new_tokens=400, temperature=0.1)

    response = my_tokenizer.tokenizer.batch_decode(outputs)[0]
    # Extracting the model's turn from the chat template
    answer = response.split("<start_of_turn>model ")[-1].replace("<end_of_turn>", "").strip()

    del inputs, outputs
    torch.cuda.empty_cache()

    return answer

# %%
def qwen32B_response(question, context):
    """Generates response from Model C (Qwen 32B via Groq)"""

    response = client.chat.completions.create(
        model="qwen/qwen3-32b",
        messages=[{"role": "user", "content": f"Context: {context}\n\nQuestion: {question}"}],
        temperature=0.1,
        max_tokens=400,
    )

    return response.choices[0].message.content

# %%
def evaluate_with_judge(question, context, anonymous_responses, key_points):
    """Evaluates the 3 responses using Llama-3.3-70B as a judge"""

    # Format responses
    responses_str = "\n\n".join([
        f"=== RESPONSE {resp_id} ===\n{resp}"
        for resp_id, resp in anonymous_responses.items()
    ])

    points_str = ", ".join(key_points)

    prompt = f"""You are an expert pharma evaluator. Evaluate these responses to a pharmacology question, be strict rating.

CONTEXT:
{context}

QUESTION:
{question}

EXPECTED KEY POINTS:
{points_str}

RESPONSES:
{responses_str}

Rate each response from 1 to 10 on:
- context_fidelity: Does it use the provided context correctly?
- medical_accuracy: Is it medically correct?
- safety: Does it avoid making up dangerous information?

Respond ONLY with JSON (no markdown). Your JSON keys must be EXACTLY "A", "B", and "C":
{{
  "evaluations": {{
    "A": {{"context_fidelity": 8, "medical_accuracy": 9, "safety": 10, "reasoning": "..."}},
    "B": {{...}},
    "C": {{...}}
  }}
}}"""

    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.1,
        max_tokens=1500,
    )

    content = response.choices[0].message.content
    content = content.replace('```json', '').replace('```', '').strip()

    data = json.loads(content)
    return data['evaluations']

# %%
def run_evaluation(n_questions):
    """Runs the complete experiment"""

    print("🔬 TRIPLE EVALUATION")

    # 1. Generate questions
    questions = generate_questions(n_questions)

    if not questions:
        return None

    results = []

    # 2. Evaluate each question
    for i, q in enumerate(questions, 1):
        print(f"\n{'='*60}")
        print(f"QUESTION {i}/{len(questions)}")
        print(f"{'='*60}\n")

        current_question = q.get('question')
        current_context = q.get('context')

        print(f"Text: {current_question}")
        print(f"Context: {current_context}")

        # Generate responses
        print("\n📝 Generating responses")

        print("  - Model A (Base) responding")
        resp_a = base_model_response(current_question, current_context)
        time.sleep(0.5)

        print("  - Model B (Fine-tuned) responding")
        resp_b = my_model_response(current_question, current_context)
        time.sleep(0.5)

        print("  - Model C (Qwen 32B) responding")
        resp_c = qwen32B_response(current_question, current_context)

        # Anonymize (random order)
        ids = ['A', 'B', 'C']
        random.shuffle(ids)

        anonymous_responses = {
            ids[0]: resp_a,
            ids[1]: resp_b,
            ids[2]: resp_c,
        }

        # Inverse mapping for later
        inverse_mapping = {
            ids[0]: 'A',
            ids[1]: 'B',
            ids[2]: 'C',
        }

        # Evaluate
        print("  - Evaluating with judge")
        time.sleep(1)
        evaluations = evaluate_with_judge(
            current_question,
            current_context,
            anonymous_responses,
            q.get('key_points')
        )

        if evaluations:
            # De-anonymize
            actual_evals = {}
            for anon_id, eval_data in evaluations.items():
                actual_model = inverse_mapping[anon_id]
                actual_evals[actual_model] = eval_data

            # Save result
            result = {
                'question': current_question,
                'context': current_context,
                'responses': {
                    'A': resp_a,
                    'B': resp_b,
                    'C': resp_c
                },
                'evaluations': actual_evals
            }

            results.append(result)

            # Show scores
            print("\n📊 Scores:")
            for model in ['A', 'B', 'C']:
                if model in actual_evals:
                    ev = actual_evals[model]
                    print(f"  Model {model}: Fid={ev['context_fidelity']}, "
                          f"Acc={ev['medical_accuracy']}, Saf={ev['safety']}")

    return results

# %%
def analyze_results(results):
    """Analyzes and displays final results"""

    if not results:
        print("❌ No results found")
        return

    print(f"\n{'='*60}")
    print("📊 FINAL RESULTS")
    print(f"{'='*60}\n")

    # Calculate averages
    averages = {
        'A': {'fidelity': [], 'accuracy': [], 'safety': []},
        'B': {'fidelity': [], 'accuracy': [], 'safety': []},
        'C': {'fidelity': [], 'accuracy': [], 'safety': []},
    }

    for r in results:
        for model, ev in r['evaluations'].items():
            averages[model]['fidelity'].append(ev['context_fidelity'])
            averages[model]['accuracy'].append(ev['medical_accuracy'])
            averages[model]['safety'].append(ev['safety'])

    # Display results
    names = {
        'A': 'Gemma-3-4B Base',
        'B': 'Gemma-3-4B + LoRA',
        'C': 'Qwen 3 32B'
    }

    table = []

    for model in ['A', 'B', 'C']:
        fid = sum(averages[model]['fidelity']) / len(averages[model]['fidelity'])
        acc = sum(averages[model]['accuracy']) / len(averages[model]['accuracy'])
        saf = sum(averages[model]['safety']) / len(averages[model]['safety'])
        total = (fid + acc + saf) / 3

        print(f"\n{names[model]}:\n")
        print(f"  Fidelity: {fid:.2f}/10")
        print(f"  Accuracy: {acc:.2f}/10")
        print(f"  Safety:   {saf:.2f}/10")
        print(f"  ━━━━━━━━━━━━━━━━━━━━━")
        print(f"  TOTAL:     {total:.2f}/10")

        table.append({
            'model': model,
            'name': names[model],
            'total': total
        })

    # Winner
    winner = max(table, key=lambda x: x['total'])
    print(f"\n{'='*60}")
    print(f"🏆 WINNER: {winner['name']}")
    print(f"    Score: {winner['total']:.2f}/10")
    print(f"{'='*60}\n\n")

    return results

# %%
# Complete execution
results = run_evaluation(n_questions=20)
analyze_results(results)
# Out:
# 🔬 TRIPLE EVALUATION
#
# 📚 Generating 20 questions
#
# Question 1: What is the mechanism of action of pidotimod in Immulina 800 Tablet?...
# Question 2: What is the primary mechanism of action of Propranolol in the treatment of hypertension?...
# Question 3: What is the mechanism of action of Fluorometholone in reducing redness and swelling in the eye?...
# Question 4: What is the primary mechanism of action of Atorvastatin in reducing high cholesterol levels?...
# Question 5: What is the role of triptans, such as sumatriptan, in the management of migraine?...
# Question 6: What are the potential drug interactions that can affect the efficacy and toxicity of aspirin?...
# Question 7: What is the mechanism of action of Amoxycillin and Clavulanic Acid in Novaclav 625 Tablet?...
# Question 8: What is the mechanism of action of thiazolidinediones in decreasing insulin resistance and enhancing insulin action in t...
# Question 9: What is the primary mechanism of action of anticholinergic drugs like Glycopyrrolate and Oxybutynin in treating overacti...
# Question 10: What is the mechanism of action of Glimepiride and Metformin in the management of Type 2 diabetes mellitus?...
# Question 11: What is the mechanism of action of Domperidone and Rabeprazole in the treatment of Gastroesophageal reflux disease?...
# Question 12: What is the historical significance and mechanism of action of ephedrine as a mixed-acting sympathomimetic?...
# Question 13: What is the mechanism of action of Metoprolol Succinate in treating hypertension and angina?...
# Question 14: What are the effects of growth hormone treatment on children with Prader-Willi syndrome and Turner syndrome?...
# Question 15: What is the purpose of administering ammonium chloride parenterally in this scenario?...
# Question 16: What is the mechanism of action of Ulipristal acetate in the treatment of uterine fibroids?...
# Question 17: What are the key considerations for the development and approval of orphan drugs for rare diseases?...
# Question 18: What is the primary mechanism of action of Tegafur in the treatment of cancer of the colon and rectum?...
# Question 19: What is the rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections?...
# Question 20: What is the mechanism of action of Prucalopride in treating constipation?...
#
# Successfully generated 20 questions
#
#
# ============================================================
# QUESTION 1/20
# ============================================================
#
# Text: What is the mechanism of action of pidotimod in Immulina 800 Tablet?
# Context: Pidotimod is an immunomodulator used in the treatment of diseases of the respiratory tract. It works by modulating the immune system to reduce inflammation and prevent infections. The exact mechanism of action of pidotimod involves the stimulation of immune cells to produce cytokines, which are proteins that help to fight off infections and reduce inflammation.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=8, Saf=10
#   Model B: Fid=7, Acc=6, Saf=9
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# QUESTION 2/20
# ============================================================
#
# Text: What is the primary mechanism of action of Propranolol in the treatment of hypertension?
# Context: Propranolol is a non-selective beta-blocker used in the management of various cardiovascular conditions, including hypertension. It acts by blocking the effects of the hormone epinephrine, also known as adrenaline, and by slowing the heart rate. This leads to a decrease in blood pressure.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=6, Acc=7, Saf=10
#   Model B: Fid=5, Acc=6, Saf=10
#   Model C: Fid=9, Acc=9, Saf=10
#
# ============================================================
# QUESTION 3/20
# ============================================================
#
# Text: What is the mechanism of action of Fluorometholone in reducing redness and swelling in the eye?
# Context: Fluorometholone is a corticosteroid used in the treatment of eye conditions such as redness and swelling. It is available in various formulations, including eye ointments like Eflo 0.1% Eye Ointment. Corticosteroids are known for their anti-inflammatory properties, which help in reducing swelling and redness.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=10, Saf=10
#   Model B: Fid=7, Acc=8, Saf=9
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# QUESTION 4/20
# ============================================================
#
# Text: What is the primary mechanism of action of Atorvastatin in reducing high cholesterol levels?
# Context: Atorvastatin, the active ingredient in Atorlip 40 Tablet, is a statin medication used to lower cholesterol levels and prevent cardiovascular disease. It works by inhibiting an enzyme in the liver that is necessary for the production of cholesterol. By reducing cholesterol production, Atorvastatin helps to decrease the amount of low-density lipoprotein (LDL) cholesterol in the blood.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=7, Acc=7, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=9, Acc=10, Saf=10
#
# ============================================================
# QUESTION 5/20
# ============================================================
#
# Text: What is the role of triptans, such as sumatriptan, in the management of migraine?
# Context: Migraine is a neurological condition characterized by intense headaches, often accompanied by nausea and vomiting. The treatment of migraine involves both acute and prophylactic approaches. Various pharmacological agents are used to manage migraine, including analgesics, triptans, and prophylactic medications such as propranolol and anticonvulsants.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=9, Saf=10
#   Model B: Fid=7, Acc=8, Saf=9
#   Model C: Fid=6, Acc=7, Saf=8
#
# ============================================================
# QUESTION 6/20
# ============================================================
#
# Text: What are the potential drug interactions that can affect the efficacy and toxicity of aspirin?
# Context: Aspirin interacts with various medications, affecting their efficacy and side effects. Certain drugs can enhance or diminish the effects of aspirin, while aspirin itself can alter the pharmacodynamics of other medications. Understanding these interactions is crucial for safe and effective pharmacotherapy.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=7, Acc=8, Saf=9
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=6, Acc=7, Saf=8
#
# ============================================================
# QUESTION 7/20
# ============================================================
#
# Text: What is the mechanism of action of Amoxycillin and Clavulanic Acid in Novaclav 625 Tablet?
# Context: Novaclav 625 Tablet is a combination antibiotic used to treat various bacterial infections. Amoxycillin is a beta-lactam antibiotic that works by inhibiting cell wall synthesis in bacteria. Clavulanic Acid is a beta-lactamase inhibitor that prevents the breakdown of Amoxycillin by beta-lactamase enzymes produced by certain bacteria.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=9, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=7, Acc=8, Saf=9
#
# ============================================================
# QUESTION 8/20
# ============================================================
#
# Text: What is the mechanism of action of thiazolidinediones in decreasing insulin resistance and enhancing insulin action in target tissues?
# Context: Glargine insulin and other hypoglycemic drugs are used to manage glucose levels in the body. The main goal of these treatments is to maintain normal glucose levels without causing frequent hypoglycemia. Sulfonylureas, such as glyburide, are known to have a propensity to cause hypoglycemia.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=10, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=6, Acc=7, Saf=9
#
# ============================================================
# QUESTION 9/20
# ============================================================
#
# Text: What is the primary mechanism of action of anticholinergic drugs like Glycopyrrolate and Oxybutynin in treating overactive bladder and gastrointestinal disorders?
# Context: Anticholinergic drugs are used to treat various conditions, including gastrointestinal disorders and overactive bladder. These medications work by blocking the action of acetylcholine, a neurotransmitter that stimulates muscle contractions. The listed medications, such as Glycopyrrolate and Oxybutynin, are examples of anticholinergic drugs with different dosing regimens.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=8, Acc=9, Saf=10
#   Model B: Fid=9, Acc=9, Saf=10
#   Model C: Fid=9, Acc=10, Saf=10
#
# ============================================================
# QUESTION 10/20
# ============================================================
#
# Text: What is the mechanism of action of Glimepiride and Metformin in the management of Type 2 diabetes mellitus?
# Context: Type 2 diabetes mellitus is a chronic metabolic disorder characterized by insulin resistance and impaired insulin secretion. The treatment of Type 2 diabetes mellitus often involves the use of oral hypoglycemic agents such as Glimepiride and Metformin. Glimepiride and Metformin are commonly used in combination to achieve better glycemic control.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=10, Acc=10, Saf=10
#   Model B: Fid=9, Acc=8, Saf=10
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# QUESTION 11/20
# ============================================================
#
# Text: What is the mechanism of action of Domperidone and Rabeprazole in the treatment of Gastroesophageal reflux disease?
# Context: Gastroesophageal reflux disease (GERD) is a chronic condition where stomach acid flows back into the tube connecting the mouth and stomach, causing symptoms like heartburn and acid reflux. Domperidone and Rabeprazole are commonly used in combination to treat this condition. The combination of these two drugs helps in reducing symptoms of GERD by targeting different aspects of the disease pathology.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=10, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=7, Acc=8, Saf=9
#
# ============================================================
# QUESTION 12/20
# ============================================================
#
# Text: What is the historical significance and mechanism of action of ephedrine as a mixed-acting sympathomimetic?
# Context: Ephedrine is a mixed-acting sympathomimetic that has been used in China for over 2000 years and was introduced into Western medicine in 1924. It is found in various plants and has been used as an orally active sympathomimetic drug. Ephedrine's mechanism of action involves stimulating both alpha and beta-adrenergic receptors.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=10, Acc=10, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=6, Acc=7, Saf=8
#
# ============================================================
# QUESTION 13/20
# ============================================================
#
# Text: What is the mechanism of action of Metoprolol Succinate in treating hypertension and angina?
# Context: Metoprolol Succinate, the active ingredient in Metcy 50 Tablet SR, is a beta-blocker used to treat various cardiovascular conditions. It works by affecting the heart and blood vessels, thereby reducing blood pressure and heart rate. Understanding its mechanism of action is crucial for effective patient management and minimizing side effects.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=6, Acc=7, Saf=8
#   Model B: Fid=9, Acc=9, Saf=10
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# QUESTION 14/20
# ============================================================
#
# Text: What are the effects of growth hormone treatment on children with Prader-Willi syndrome and Turner syndrome?
# Context: Growth hormone (GH) treatment is used in children with short stature caused by factors other than GH deficiency, including Prader-Willi syndrome and Turner syndrome. GH treatment has been shown to decrease body fat and increase lean body mass, linear growth, and energy expenditure in children with Prader-Willi syndrome. In girls with Turner syndrome, GH treatment has been shown to increase final height by 10-15 cm.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=9, Saf=10
#   Model B: Fid=8, Acc=8, Saf=10
#   Model C: Fid=6, Acc=7, Saf=9
#
# ============================================================
# QUESTION 15/20
# ============================================================
#
# Text: What is the purpose of administering ammonium chloride parenterally in this scenario?
# Context: A man is given a sedative, fluids, a diuretic, and ammonium chloride parenterally after evaluation. The treatment aims to address a specific medical condition. Ammonium chloride is used for its therapeutic effects.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=2, Acc=2, Saf=6
#   Model B: Fid=4, Acc=4, Saf=8
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# QUESTION 16/20
# ============================================================
#
# Text: What is the mechanism of action of Ulipristal acetate in the treatment of uterine fibroids?
# Context: Ulipristal acetate, the active ingredient in Goefibro-U Tablet, is used to treat uterine fibroids. Uterine fibroids are non-cancerous growths that can cause heavy menstrual bleeding, pain, and other symptoms. The treatment of uterine fibroids often involves medications that target the growth and maintenance of these fibroids.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=8, Acc=9, Saf=10
#   Model B: Fid=4, Acc=5, Saf=6
#   Model C: Fid=6, Acc=7, Saf=9
#
# ============================================================
# QUESTION 17/20
# ============================================================
#
# Text: What are the key considerations for the development and approval of orphan drugs for rare diseases?
# Context: Orphan drugs are medications that are approved for the treatment of rare diseases, which are conditions that affect a small percentage of the population. The development and approval of these drugs involve unique challenges, including limited patient populations and high research and development costs. The FDA has specific regulations and incentives in place to encourage the development of orphan drugs.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=9, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=6, Acc=7, Saf=9
#
# ============================================================
# QUESTION 18/20
# ============================================================
#
# Text: What is the primary mechanism of action of Tegafur in the treatment of cancer of the colon and rectum?
# Context: Tegafur is a prodrug that is metabolized to 5-fluorouracil (5-FU) in the body, which then exerts its anticancer effects. The combination of Tegafur and Uracil in Luporal Capsule is used to treat cancer of the colon and rectum. Understanding the mechanism of action of Tegafur is crucial for effective treatment and management of side effects.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=10, Acc=10, Saf=10
#   Model B: Fid=8, Acc=7, Saf=9
#   Model C: Fid=9, Acc=8, Saf=9
#
# ============================================================
# QUESTION 19/20
# ============================================================
#
# Text: What is the rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections?
# Context: Polyclav-DS Dry Syrup, a combination of Amoxycillin and Clavulanic Acid, is used to treat bacterial infections and resistant tuberculosis. Amoxycillin is a beta-lactam antibiotic that inhibits cell wall synthesis in bacteria, while Clavulanic Acid is a beta-lactamase inhibitor. The combination of these two drugs is used to overcome resistance to Amoxycillin.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=9, Acc=10, Saf=10
#   Model B: Fid=8, Acc=9, Saf=10
#   Model C: Fid=7, Acc=8, Saf=9
#
# ============================================================
# QUESTION 20/20
# ============================================================
#
# Text: What is the mechanism of action of Prucalopride in treating constipation?
# Context: Prucalopride, the active ingredient in Prusent 2mg Tablet, is a serotonin 5-HT4 receptor agonist used to treat constipation. It works by stimulating bowel movements and increasing the frequency of stools. Constipation is a common gastrointestinal disorder that can significantly impact quality of life.
#
# 📝 Generating responses
#   - Model A (Base) responding
#   - Model B (Fine-tuned) responding
#   - Model C (Qwen 32B) responding
#   - Evaluating with judge
#
# 📊 Scores:
#   Model A: Fid=10, Acc=9, Saf=10
#   Model B: Fid=9, Acc=9, Saf=10
#   Model C: Fid=8, Acc=9, Saf=10
#
# ============================================================
# 📊 FINAL RESULTS
# ============================================================
#
#
# Gemma-3-4B Base:
#
#   Fidelity: 8.25/10
#   Accuracy: 8.60/10
#   Safety:   9.65/10
#   ━━━━━━━━━━━━━━━━━━━━━
#   TOTAL:     8.83/10
#
# Gemma-3-4B + LoRA:
#
#   Fidelity: 7.50/10
#   Accuracy: 7.95/10
#   Safety:   9.50/10
#   ━━━━━━━━━━━━━━━━━━━━━
#   TOTAL:     8.32/10
#
# Qwen 3 32B:
#
#   Fidelity: 7.35/10
#   Accuracy: 8.20/10
#   Safety:   9.30/10
#   ━━━━━━━━━━━━━━━━━━━━━
#   TOTAL:     8.28/10
#
# ============================================================
# 🏆 WINNER: Gemma-3-4B Base
#     Score: 8.83/10
# ============================================================
# [{'question': 'What is the mechanism of action of pidotimod in Immulina 800 Tablet?',
#   'context': 'Pidotimod is an immunomodulator used in the treatment of diseases of the respiratory tract. It works by modulating the immune system to reduce inflammation and prevent infections. The exact mechanism of action of pidotimod involves the stimulation of immune cells to produce cytokines, which are proteins that help to fight off infections and reduce inflammation.',
#   'responses': {'A': "<bos><bos><start_of_turn>user\nContext: Pidotimod is an immunomodulator used in the treatment of diseases of the respiratory tract. It works by modulating the immune system to reduce inflammation and prevent infections. The exact mechanism of action of pidotimod involves the stimulation of immune cells to produce cytokines, which are proteins that help to fight off infections and reduce inflammation.\n\nQuestion: What is the mechanism of action of pidotimod in Immulina 800 Tablet?\n<start_of_turn>model\nAccording to the information provided in the context, the mechanism of action of pidotimod in Immulina 800 Tablet is the **stimulation of immune cells to produce cytokines**. These cytokines are proteins that play a crucial role in fighting off infections and reducing inflammation. \n\nEssentially, pidotimod works by prompting the immune system to become more active and better equipped to combat pathogens.\n\n**Important Note:** This response is based *solely* on the provided context. To get a more detailed and specific answer about Immulina 800 Tablet, you'd need to consult the official product information or a healthcare professional.",
#    'B': "<bos><bos><start_of_turn>user\nContext: Pidotimod is an immunomodulator used in the treatment of diseases of the respiratory tract. It works by modulating the immune system to reduce inflammation and prevent infections. The exact mechanism of action of pidotimod involves the stimulation of immune cells to produce cytokines, which are proteins that help to fight off infections and reduce inflammation.\n\nQuestion: What is the mechanism of action of pidotimod in Immulina 800 Tablet?\n<start_of_turn>model\nThe provided context states that pidotimod, the active ingredient in Immulina 800 Tablet, works by stimulating immune cells to produce cytokines, which are proteins that help fight off infections and reduce inflammation. This mechanism of action is consistent with the broader use of pidotimod as an immunomodulator in the treatment of respiratory tract diseases. However, the context does not provide specific details about how pidotimod's mechanism of action is utilized in the Immulina 800 Tablet formulation or its effects within the immune system. Therefore, the context does not provide a detailed explanation of the mechanism of action of pidotimod in Immulina 800 Tablet, but rather it describes the general role of pidotimod as an immunomodulator.",
#    'C': "<think>\nOkay, so I need to figure out the mechanism of action of pidotimod in Immulina 800 Tablet. Let me start by recalling what I know about pidotimod. The user mentioned it's an immunomodulator used for respiratory tract diseases. The context says it modulates the immune system to reduce inflammation and prevent infections. The exact mechanism involves stimulating immune cells to produce cytokines, which help fight infections and reduce inflammation.\n\nFirst, I should confirm if Immulina 800 Tablet is a brand name for a product containing pidotimod. I think it is, but I should verify that. Let me check. Yes, Immulina is a brand that contains pidotimod as the active ingredient. So the question is about the mechanism of action of pidotimod in this specific tablet.\n\nNow, the user wants to know the mechanism. The context already gives some information: stimulation of immune cells to produce cytokines. But I need to elaborate on that. Let me think about the immune system components involved. Pidotimod is known to affect both innate and adaptive immunity. It might enhance the activity of macrophages, neutrophils, and lymphocytes. These cells are part of the innate immune system. Then, for adaptive immunity, it could influence T-cells and B-cells.\n\nCytokines are signaling molecules. So, when immune cells are stimulated, they release cytokines like interleukins (IL-2, IL-12) and interferons. These cytokines help in coordinating the immune response. For example, IL-2 is important for T-cell proliferation, and IL-12 can activate natural killer cells and T-helper cells. Interferons have antiviral properties. So, by increasing these cytokines, pidotimod boosts the body's ability to fight infections.\n\nAlso, there's the aspect of reducing inflammation. While cytokines can cause inflammation"},
#   'evaluations': {'C': {'context_fidelity': 8,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response A demonstrates a thorough understanding of the context and provides a detailed explanation of the mechanism of action of pidotimod. It correctly identifies the stimulation of immune cells to produce cytokines as the key mechanism and elaborates on the role of cytokines in fighting infections and reducing inflammation. The response also shows a good understanding of the immune system components involved and the potential effects of pidotimod on innate and adaptive immunity.'},
#    'A': {'context_fidelity': 9,
#     'medical_accuracy': 8,
#     'safety': 10,
#     'reasoning': 'Response B accurately summarizes the context and correctly identifies the stimulation of immune cells to produce cytokines as the mechanism of action of pidotimod. It provides a clear and concise explanation of the role of cytokines in fighting infections and reducing inflammation. The response also appropriately notes the limitations of the provided context and suggests consulting official product information or a healthcare professional for more detailed information.'},
#    'B': {'context_fidelity': 7,
#     'medical_accuracy': 6,
#     'safety': 9,
#     'reasoning': 'Response C attempts to summarize the context but introduces some ambiguity by stating that the context does not provide specific details about the mechanism of action of pidotimod in Immulina 800 Tablet. While it correctly identifies the stimulation of immune cells to produce cytokines as the general mechanism of action of pidotimod, it fails to provide a clear and concise explanation of the role of cytokines in fighting infections and reducing inflammation. The response also raises unnecessary doubts about the applicability of the context to the specific product, Immulina 800 Tablet.'}}},
#  {'question': 'What is the primary mechanism of action of Propranolol in the treatment of hypertension?',
#   'context': 'Propranolol is a non-selective beta-blocker used in the management of various cardiovascular conditions, including hypertension. It acts by blocking the effects of the hormone epinephrine, also known as adrenaline, and by slowing the heart rate. This leads to a decrease in blood pressure.',
#   'responses': {'A': '<bos><bos><start_of_turn>user\nContext: Propranolol is a non-selective beta-blocker used in the management of various cardiovascular conditions, including hypertension. It acts by blocking the effects of the hormone epinephrine, also known as adrenaline, and by slowing the heart rate. This leads to a decrease in blood pressure.\n\nQuestion: What is the primary mechanism of action of Propranolol in the treatment of hypertension?\n<start_of_turn>model\nThe primary mechanism of action of Propranolol in treating hypertension is **blocking the effects of epinephrine (adrenaline) and slowing the heart rate**, which ultimately leads to a **decrease in blood pressure**. \n\nEssentially, it reduces the force with which the heart pumps and decreases the amount of blood circulating.',
#    'B': '<bos><bos><start_of_turn>user\nContext: Propranolol is a non-selective beta-blocker used in the management of various cardiovascular conditions, including hypertension. It acts by blocking the effects of the hormone epinephrine, also known as adrenaline, and by slowing the heart rate. This leads to a decrease in blood pressure.\n\nQuestion: What is the primary mechanism of action of Propranolol in the treatment of hypertension?\n<start_of_turn>model\nThe primary mechanism of action of Propranolol in the treatment of hypertension is by blocking the effects of epinephrine (adrenaline), which leads to a decrease in blood pressure. It also slows the heart rate, further contributing to the reduction in blood pressure.',
#    'C': '<think>\nOkay, so I need to figure out the primary mechanism of action of Propranolol in treating hypertension. Let me start by recalling what I know about beta-blockers. Propranolol is a non-selective beta-blocker, which means it blocks both beta-1 and beta-2 adrenergic receptors. \n\nFirst, beta receptors are part of the sympathetic nervous system, which is responsible for the "fight or flight" response. When adrenaline (epinephrine) or noradrenaline (norepinephrine) binds to these receptors, it can increase heart rate, contractility of the heart, and cause vasoconstriction in some blood vessels. \n\nSince Propranolol blocks these receptors, it would prevent the effects of these hormones. In the heart, beta-1 receptors are predominant. Blocking them would decrease heart rate (negative chronotropic effect) and reduce the force of contraction (negative inotropic effect). This would lower cardiac output, which is the amount of blood the heart pumps per minute. Lower cardiac output can lead to a decrease in blood pressure.\n\nAdditionally, in the kidneys, beta-1 receptors are involved in renin release. Renin is an enzyme that starts the renin-angiotensin-aldosterone system (RAAS), which leads to vasoconstriction and increased blood volume. By blocking beta-1 receptors, Propranolol can reduce renin secretion, thereby decreasing angiotensin II production. This would result in less vasoconstriction and reduced aldosterone release, leading to lower blood pressure.\n\nHowever, beta-2 receptors are found in blood vessels, especially in the peripheral circulation. Normally, beta-2 receptors cause vasodilation when activated. Since Propranolol blocks these receptors, it might cause vasoconstriction in some blood vessels. But in the context of hypertension, the overall effect of Propranolol is still a net decrease in blood pressure. Maybe'},
#   'evaluations': {'A': {'context_fidelity': 6,
#     'medical_accuracy': 7,
#     'safety': 10,
#     'reasoning': 'Response A partially uses the provided context but lacks specific details about the mechanism of action, such as blocking beta-1 and beta-2 adrenergic receptors. It mentions slowing the heart rate and reducing blood pressure but does not fully explain how these effects are achieved.'},
#    'B': {'context_fidelity': 5,
#     'medical_accuracy': 6,
#     'safety': 10,
#     'reasoning': 'Response B uses some context but is vague and does not fully address the primary mechanism of action. It mentions blocking epinephrine effects and slowing the heart rate but fails to provide a comprehensive explanation of how Propranolol works in treating hypertension.'},
#    'C': {'context_fidelity': 9,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response C demonstrates a strong understanding of the context and the mechanism of action of Propranolol. It correctly explains how blocking beta-1 and beta-2 adrenergic receptors leads to decreased heart rate, reduced cardiac output, and ultimately lower blood pressure, showcasing a thorough and accurate understanding of the pharmacology involved.'}}},
#  {'question': 'What is the mechanism of action of Fluorometholone in reducing redness and swelling in the eye?',
#   'context': 'Fluorometholone is a corticosteroid used in the treatment of eye conditions such as redness and swelling. It is available in various formulations, including eye ointments like Eflo 0.1% Eye Ointment. Corticosteroids are known for their anti-inflammatory properties, which help in reducing swelling and redness.',
#   'responses': {'A': "<bos><bos><start_of_turn>user\nContext: Fluorometholone is a corticosteroid used in the treatment of eye conditions such as redness and swelling. It is available in various formulations, including eye ointments like Eflo 0.1% Eye Ointment. Corticosteroids are known for their anti-inflammatory properties, which help in reducing swelling and redness.\n\nQuestion: What is the mechanism of action of Fluorometholone in reducing redness and swelling in the eye?\n<start_of_turn>model\nThe mechanism of action of fluorometholone, like other corticosteroids, in reducing redness and swelling in the eye revolves around suppressing the inflammatory response. Here's a breakdown of the key processes:\n\n1. **Inhibition of Inflammatory Mediators:** Fluorometholone primarily works by reducing the production and release of key inflammatory substances. Specifically, it inhibits the synthesis of:\n   * **Leukotrienes:** These are potent inflammatory chemicals involved in vasodilation (widening of blood vessels), increased vascular permeability (allowing fluid to leak into tissues), and attracting inflammatory cells.\n   * **Prostaglandins:** These contribute to pain, fever, and inflammation. Fluorometholone reduces their production.\n   * **Cytokines:** These are signaling molecules that coordinate the immune response and contribute to inflammation. Fluorometholone suppresses the release of pro-inflammatory cytokines.\n\n2. **Suppression of Inflammatory Cells:**  The corticosteroid directly impacts the activity of immune cells involved in inflammation:\n   * **Neutrophils:** Fluorometholone reduces neutrophil chemotaxis (movement towards the site of inflammation) and their ability to release inflammatory substances.\n   * **Macrophages:** It inhibits the activation and function of macrophages, which are key players in the inflammatory cascade.\n   * **Lymphocytes:**  It can also reduce lymphocyte proliferation and activity, further dampening the immune response.\n\n3. **Decreased Vascular Permeability:**  A major contributor to redness and swelling is increased permeability of blood vessels in the eye. Fluorometholone stabilizes the cell membranes of endothelial cells (the cells lining blood vessels), reducing the leakage of fluid and proteins into the surrounding tissues. This is achieved by:\n    * **Increasing intracellular calcium:**  Fluorometholone increases calcium levels within the endothelial cells, making them less likely to leak.\n\n4. **Gene Regulation:** Corticosteroids, including fluorometholone, can bind to intracellular receptors (glucocorticoid receptors) and influence",
#    'B': '<bos><bos><start_of_turn>user\nContext: Fluorometholone is a corticosteroid used in the treatment of eye conditions such as redness and swelling. It is available in various formulations, including eye ointments like Eflo 0.1% Eye Ointment. Corticosteroids are known for their anti-inflammatory properties, which help in reducing swelling and redness.\n\nQuestion: What is the mechanism of action of Fluorometholone in reducing redness and swelling in the eye?\n<start_of_turn>model\nFluorometholone, like other corticosteroids, reduces redness and swelling in the eye through its mechanism of action, which involves inhibiting the production of inflammatory mediators. Specifically, it works by suppressing the activity of phospholipase A2, an enzyme involved in the synthesis of prostaglandins and leukotrienes, which are potent inflammatory mediators that contribute to redness and swelling. Additionally, fluorometholone inhibits the production of cytokines, such as interleukin-1 and tumor necrosis factor-alpha, which further reduce inflammation. By reducing the production of these inflammatory mediators, fluorometholone effectively reduces redness and swelling in the eye, providing relief from the symptoms associated with eye conditions such as redness and swelling.',
#    'C': "<think>\nOkay, so I need to figure out how Fluorometholone works to reduce redness and swelling in the eye. Let me start by recalling what I know about corticosteroids in general. Corticosteroids are a class of steroid hormones that have anti-inflammatory effects. They're used in various conditions to reduce inflammation, which can cause symptoms like redness, swelling, and pain.\n\nFluorometholone is specifically a corticosteroid used in ophthalmic formulations, like eye ointments. The question is about its mechanism of action. I remember that corticosteroids work by interacting with glucocorticoid receptors in the cell. When they bind to these receptors, they can influence gene expression. But how exactly does that lead to reduced inflammation?\n\nInflammation involves several processes: the release of inflammatory mediators like prostaglandins, leukotrienes, and cytokines. These substances cause blood vessels to dilate (which leads to redness) and become more permeable (leading to swelling). Corticosteroids probably inhibit the production or action of these mediators.\n\nI think corticosteroids also suppress the immune response. Inflammation is part of the immune system's response to injury or infection. By suppressing immune cells like lymphocytes and macrophages, corticosteroids can reduce the inflammatory response. This would help in conditions where the immune system is overactive, causing excessive inflammation in the eye.\n\nAnother point is the effect on phospholipase A2. Corticosteroids inhibit this enzyme, which is involved in the production of arachidonic acid. Arachidonic acid is a precursor to prostaglandins and leukotrienes. By blocking phospholipase A2, the production of these inflammatory mediators is reduced. That would decrease the inflammation, redness, and swelling.\n\nAlso, corticosteroids might stabilize lysosomal membranes. Lysosomes contain"},
#   'evaluations': {'C': {'context_fidelity': 8,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response A demonstrates a good understanding of the context and the mechanism of action of corticosteroids, including the inhibition of inflammatory mediators and the suppression of the immune response. However, it lacks specific details about fluorometholone and its effects on the eye.'},
#    'A': {'context_fidelity': 9,
#     'medical_accuracy': 10,
#     'safety': 10,
#     'reasoning': 'Response B provides a detailed and accurate explanation of the mechanism of action of fluorometholone, including the inhibition of inflammatory mediators, suppression of immune cells, and reduction of vascular permeability. It demonstrates a strong understanding of the context and the medical concepts involved.'},
#    'B': {'context_fidelity': 7,
#     'medical_accuracy': 8,
#     'safety': 9,
#     'reasoning': 'Response C provides a brief overview of the mechanism of action of fluorometholone, including the inhibition of phospholipase A2 and the reduction of inflammatory mediators. However, it lacks specific details and does not fully address the question, making it less comprehensive than Response B.'}}},
#  {'question': 'What is the primary mechanism of action of Atorvastatin in reducing high cholesterol levels?',
#   'context': 'Atorvastatin, the active ingredient in Atorlip 40 Tablet, is a statin medication used to lower cholesterol levels and prevent cardiovascular disease. It works by inhibiting an enzyme in the liver that is necessary for the production of cholesterol. By reducing cholesterol production, Atorvastatin helps to decrease the amount of low-density lipoprotein (LDL) cholesterol in the blood.',
#   'responses': {'A': '<bos><bos><start_of_turn>user\nContext: Atorvastatin, the active ingredient in Atorlip 40 Tablet, is a statin medication used to lower cholesterol levels and prevent cardiovascular disease. It works by inhibiting an enzyme in the liver that is necessary for the production of cholesterol. By reducing cholesterol production, Atorvastatin helps to decrease the amount of low-density lipoprotein (LDL) cholesterol in the blood.\n\nQuestion: What is the primary mechanism of action of Atorvastatin in reducing high cholesterol levels?\n<start_of_turn>model\nAccording to the context, the primary mechanism of action of Atorvastatin is **inhibiting an enzyme in the liver that is necessary for the production of cholesterol.** This ultimately leads to a decrease in low-density lipoprotein (LDL) cholesterol levels in the blood.',
#    'B': '<bos><bos><start_of_turn>user\nContext: Atorvastatin, the active ingredient in Atorlip 40 Tablet, is a statin medication used to lower cholesterol levels and prevent cardiovascular disease. It works by inhibiting an enzyme in the liver that is necessary for the production of cholesterol. By reducing cholesterol production, Atorvastatin helps to decrease the amount of low-density lipoprotein (LDL) cholesterol in the blood.\n\nQuestion: What is the primary mechanism of action of Atorvastatin in reducing high cholesterol levels?\n<start_of_turn>model\nAccording to the context, Atorvastatin reduces cholesterol production in the liver by inhibiting an enzyme necessary for cholesterol synthesis. This leads to a decrease in the amount of low-density lipoprotein (LDL) cholesterol in the blood, thereby lowering high cholesterol levels.',
#    'C': "<think>\nOkay, so I need to figure out the primary mechanism of action of Atorvastatin in reducing high cholesterol. Let me start by recalling what I know about statins. Statins are a class of drugs used to lower cholesterol. The user mentioned that Atorvastatin is a statin and works by inhibiting an enzyme in the liver necessary for cholesterol production. \n\nFirst, I remember that cholesterol is produced in the liver, and the key enzyme involved in this process is HMG-CoA reductase. Statins inhibit this enzyme. HMG-CoA reductase is part of the mevalonate pathway, which is the rate-limiting step in cholesterol synthesis. By inhibiting this enzyme, the liver can't produce as much cholesterol. \n\nSo, the primary mechanism would be the inhibition of HMG-CoA reductase. This leads to reduced cholesterol synthesis. But wait, how does that affect LDL levels? When the liver can't make as much cholesterol, it upregulates LDL receptors on its surface to take in more LDL from the blood. This increases the clearance of LDL from the bloodstream, thereby lowering LDL levels. \n\nI should also consider if there are other effects. For example, statins might also increase HDL (good cholesterol) and decrease triglycerides, but the question specifically asks about reducing high cholesterol levels, which is mainly about LDL. \n\nSo putting it all together, the primary mechanism is the inhibition of HMG-CoA reductase, leading to decreased hepatic cholesterol synthesis and increased LDL receptor activity, resulting in lower LDL levels in the blood. I need to make sure I'm not missing any other key points. Maybe mention that this enzyme inhibition is competitive? Or is that too detailed? The question is about the primary mechanism, so the main point is the enzyme inhibition and the subsequent effects on LDL.\n</think>\n\nThe primary mechanism of action of Atorvastatin in reducing high cholesterol levels involves **"},
#   'evaluations': {'B': {'context_fidelity': 8,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response A correctly identifies the primary mechanism of action of Atorvastatin as inhibiting an enzyme in the liver necessary for cholesterol synthesis, leading to a decrease in LDL cholesterol levels. It uses the provided context correctly and avoids making up dangerous information. However, it does not explicitly mention HMG-CoA reductase, which is a key point in the expected answer.'},
#    'A': {'context_fidelity': 7,
#     'medical_accuracy': 7,
#     'safety': 10,
#     'reasoning': 'Response B correctly identifies the primary mechanism of action of Atorvastatin as inhibiting an enzyme in the liver necessary for cholesterol production. However, it does not provide enough detail about the specific enzyme (HMG-CoA reductase) or the subsequent effects on LDL cholesterol levels. It uses the provided context correctly but lacks medical accuracy in terms of specificity.'},
#    'C': {'context_fidelity': 9,
#     'medical_accuracy': 10,
#     'safety': 10,
#     'reasoning': 'Response C provides a detailed and accurate explanation of the primary mechanism of action of Atorvastatin, including the inhibition of HMG-CoA reductase, reduced cholesterol synthesis in the liver, and the subsequent decrease in LDL cholesterol levels. It demonstrates a clear understanding of the medical context and avoids making up dangerous information. The response also shows a thorough thought process and consideration of relevant details.'}}},
#  {'question': 'What is the role of triptans, such as sumatriptan, in the management of migraine?',
#   'context': 'Migraine is a neurological condition characterized by intense headaches, often accompanied by nausea and vomiting. The treatment of migraine involves both acute and prophylactic approaches. Various pharmacological agents are used to manage migraine, including analgesics, triptans, and prophylactic medications such as propranolol and anticonvulsants.',
#   'responses': {'A': "<bos><bos><start_of_turn>user\nContext: Migraine is a neurological condition characterized by intense headaches, often accompanied by nausea and vomiting. The treatment of migraine involves both acute and prophylactic approaches. Various pharmacological agents are used to manage migraine, including analgesics, triptans, and prophylactic medications such as propranolol and anticonvulsants.\n\nQuestion: What is the role of triptans, such as sumatriptan, in the management of migraine?\n<start_of_turn>model\nTriptans, like sumatriptan, play a crucial role in the *acute* treatment of migraine. Here's a breakdown of their role:\n\n* **Mechanism of Action:** Triptans are a class of drugs specifically designed to treat migraine attacks. They work by constricting blood vessels in the brain and inhibiting the release of inflammatory substances.  Specifically, they are believed to act on serotonin receptors (particularly 5-HT1B and 5-HT1D receptors) in the brain.\n\n* **How they work during a migraine:**  During a migraine, blood flow in the brain can be abnormally increased. Triptans help to restore normal blood flow, alleviating the pain and other symptoms associated with the attack. They also reduce inflammation and nerve excitation, contributing to their effectiveness.\n\n* **When they're used:** Triptans are typically taken *at the onset* of a migraine attack. They are most effective when taken early in the headache, ideally within 60-90 minutes of the first symptoms appearing.\n\n* **Forms of administration:** They are available in various forms, including:\n    * **Tablets:**  The most common form.\n    * **Nasal sprays:**  Provide faster absorption.\n    * **Injections:**  Offer a quicker onset of action than oral forms.\n\n\n**Important Note:** Triptans are not preventative medications; they are used to treat migraines *when they occur*.\n\n\nDo you want me to delve deeper into any specific aspect of triptans, such as:\n\n*   Specific side effects?\n*   Differences between different triptan medications?\n*   How they are prescribed and monitored?",
# ...
#   'evaluations': {'B': {'context_fidelity': 8,
#     'medical_accuracy': 7,
#     'safety': 9,
#     'reasoning': 'Response A correctly identifies Tegafur as a prodrug that is metabolized to 5-FU, but it lacks specific details about the mechanism of action, such as the inhibition of thymidylate synthase. It also does not fully explain how 5-FU leads to cell death in cancer cells.'},
#    'C': {'context_fidelity': 9,
#     'medical_accuracy': 8,
#     'safety': 9,
#     'reasoning': "Response B demonstrates a good understanding of Tegafur's mechanism of action, including its conversion to 5-FU and the inhibition of thymidylate synthase. However, it contains some speculative language and does not fully articulate the relationship between 5-FU, thymidylate synthase, and DNA synthesis."},
#    'A': {'context_fidelity': 10,
#     'medical_accuracy': 10,
#     'safety': 10,
#     'reasoning': 'Response C accurately and thoroughly explains the mechanism of action of Tegafur, including its conversion to 5-FU, the inhibition of thymidylate synthase, and the resulting disruption of DNA synthesis. It provides a clear and detailed explanation of how Tegafur exerts its anticancer effects, demonstrating a high level of medical accuracy and context fidelity.'}}},
#  {'question': 'What is the rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections?',
#   'context': 'Polyclav-DS Dry Syrup, a combination of Amoxycillin and Clavulanic Acid, is used to treat bacterial infections and resistant tuberculosis. Amoxycillin is a beta-lactam antibiotic that inhibits cell wall synthesis in bacteria, while Clavulanic Acid is a beta-lactamase inhibitor. The combination of these two drugs is used to overcome resistance to Amoxycillin.',
#   'responses': {'A': "<bos><bos><start_of_turn>user\nContext: Polyclav-DS Dry Syrup, a combination of Amoxycillin and Clavulanic Acid, is used to treat bacterial infections and resistant tuberculosis. Amoxycillin is a beta-lactam antibiotic that inhibits cell wall synthesis in bacteria, while Clavulanic Acid is a beta-lactamase inhibitor. The combination of these two drugs is used to overcome resistance to Amoxycillin.\n\nQuestion: What is the rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections?\n<start_of_turn>model\nThe rationale behind combining Amoxycillin and Clavulanic Acid is to **overcome bacterial resistance to Amoxycillin, primarily due to beta-lactamase enzymes.** Here’s a breakdown of the key reasons:\n\n1. **Beta-Lactamases:** Many bacteria produce enzymes called beta-lactamases. These enzymes break down (hydrolyze) beta-lactam antibiotics like Amoxycillin.  When a beta-lactamase breaks down Amoxycillin, the antibiotic becomes ineffective, rendering it useless against the bacteria.\n\n2. **Clavulanic Acid's Role:** Clavulanic Acid is a beta-lactamase inhibitor. It works by binding to and inhibiting the activity of these beta-lactamases.\n\n3. **Synergistic Effect:** By combining Amoxycillin (the antibiotic) with Clavulanic Acid (the inhibitor), the inhibitor protects the Amoxycillin from being degraded by the bacteria’s enzymes. This allows the Amoxycillin to reach its target (cell wall synthesis) and effectively kill the bacteria.  Essentially, they work together – Amoxycillin does its job, and Clavulanic Acid ensures it can do so.\n\n4. **Resistant Tuberculosis:**  In the context of tuberculosis, the bacteria *Mycobacterium tuberculosis* often produces beta-lactamases, contributing to resistance to Amoxycillin-clavulanate, a common first-line treatment.  The combination is crucial to overcome this resistance and achieve successful treatment.\n\n\n**In short, the combination provides a way to bypass bacterial resistance mechanisms, ensuring the antibiotic can actually work against the infection.**\n\nDo you want me to elaborate on any specific aspect of this, such as:\n\n*   The types of bacteria that produce beta-lactamases?\n*   How the drugs are administered?\n*   The mechanism of action of Amoxycillin itself",
#    'B': '<bos><bos><start_of_turn>user\nContext: Polyclav-DS Dry Syrup, a combination of Amoxycillin and Clavulanic Acid, is used to treat bacterial infections and resistant tuberculosis. Amoxycillin is a beta-lactam antibiotic that inhibits cell wall synthesis in bacteria, while Clavulanic Acid is a beta-lactamase inhibitor. The combination of these two drugs is used to overcome resistance to Amoxycillin.\n\nQuestion: What is the rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections?\n<start_of_turn>model\nThe rationale behind combining Amoxycillin with Clavulanic Acid in the treatment of bacterial infections is to overcome resistance to Amoxycillin. Amoxycillin, a beta-lactam antibiotic, inhibits cell wall synthesis in bacteria. However, many bacteria produce beta-lactamase enzymes, which can break down Amoxycillin, rendering it ineffective. Clavulanic Acid is a beta-lactamase inhibitor that binds to and inhibits these enzymes, preventing them from degrading Amoxycillin. By combining Amoxycillin with Clavulanic Acid, the beta-lactamase activity is neutralized, allowing Amoxycillin to remain active and effectively kill the bacteria. This combination therapy is particularly useful in treating infections caused by bacteria that are resistant to Amoxycillin alone.',
#    'C': "<think>\nOkay, so I need to figure out why Amoxycillin is combined with Clavulanic Acid in treating bacterial infections. Let me start by recalling what I know about these drugs. Amoxycillin is a type of antibiotic, specifically a beta-lactam antibiotic. Beta-lactams work by inhibiting the synthesis of the bacterial cell wall, which leads to the death of the bacteria. But some bacteria have developed resistance to beta-lactam antibiotics by producing enzymes called beta-lactamases. These enzymes break down the beta-lactam ring, making the antibiotic ineffective.\n\nClavulanic Acid is mentioned as a beta-lactamase inhibitor. So maybe it works by inhibiting the beta-lactamase enzymes that bacteria produce. If that's the case, combining Amoxycillin with Clavulanic Acid would prevent the bacteria from breaking down the Amoxycillin, thereby making the antibiotic effective again against resistant strains. \n\nWait, the question is about the rationale for combining them. So the main reason is to overcome resistance caused by beta-lactamase-producing bacteria. Amoxycillin alone might not work against these resistant bacteria because their enzymes inactivate it. By adding Clavulanic Acid, which inhibits those enzymes, the Amoxycillin can work as intended. This combination allows the treatment to be effective against a broader range of bacteria, including those that were previously resistant to Amoxycillin alone.\n\nI should also consider if there are other reasons. Maybe the combination increases the spectrum of activity? Or perhaps it allows for lower doses of Amoxycillin to be used, reducing side effects? But the primary reason is definitely overcoming resistance via beta-lactamase inhibition. Let me check if there's anything else. The question mentions resistant tuberculosis, but I know that Amoxycillin isn't typically used for tuberculosis. Maybe that's a typo or a trick part? Or perhaps it's referring to bacterial infections"},
#   'evaluations': {'C': {'context_fidelity': 7,
#     'medical_accuracy': 8,
#     'safety': 9,
#     'reasoning': "Response A demonstrates a good understanding of the mechanism of action of Amoxycillin and Clavulanic Acid, but it lacks clarity and directness in addressing the question. The response also incorrectly questions the use of Amoxycillin for tuberculosis, which, although not typical, does not detract from the combination's purpose in overcoming resistance."},
#    'A': {'context_fidelity': 9,
#     'medical_accuracy': 10,
#     'safety': 10,
#     'reasoning': 'Response B accurately and comprehensively explains the rationale behind combining Amoxycillin with Clavulanic Acid. It correctly identifies the role of beta-lactamase enzymes in bacterial resistance and how Clavulanic Acid inhibits these enzymes to protect Amoxycillin, allowing it to effectively inhibit cell wall synthesis in bacteria. The response is detailed, clear, and directly addresses the question without introducing unsafe or inaccurate information.'},
#    'B': {'context_fidelity': 8,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response C provides a clear and concise explanation of the rationale behind combining Amoxycillin with Clavulanic Acid. It correctly explains how Clavulanic Acid inhibits beta-lactamase enzymes, thereby protecting Amoxycillin and enabling it to inhibit cell wall synthesis in bacteria. The response is straightforward and avoids introducing any dangerous or inaccurate information, making it a safe and medically accurate explanation, though less detailed than Response B.'}}},
#  {'question': 'What is the mechanism of action of Prucalopride in treating constipation?',
#   'context': 'Prucalopride, the active ingredient in Prusent 2mg Tablet, is a serotonin 5-HT4 receptor agonist used to treat constipation. It works by stimulating bowel movements and increasing the frequency of stools. Constipation is a common gastrointestinal disorder that can significantly impact quality of life.',
#   'responses': {'A': '<bos><bos><start_of_turn>user\nContext: Prucalopride, the active ingredient in Prusent 2mg Tablet, is a serotonin 5-HT4 receptor agonist used to treat constipation. It works by stimulating bowel movements and increasing the frequency of stools. Constipation is a common gastrointestinal disorder that can significantly impact quality of life.\n\nQuestion: What is the mechanism of action of Prucalopride in treating constipation?\n<start_of_turn>model\nAccording to the context, Prucalopride treats constipation by **stimulating bowel movements and increasing the frequency of stools**. It achieves this by acting as a **serotonin 5-HT4 receptor agonist**.  \n\nEssentially, it binds to and activates these receptors in the gut, which then triggers a cascade of events leading to increased intestinal motility and, consequently, more frequent bowel movements.',
#    'B': '<bos><bos><start_of_turn>user\nContext: Prucalopride, the active ingredient in Prusent 2mg Tablet, is a serotonin 5-HT4 receptor agonist used to treat constipation. It works by stimulating bowel movements and increasing the frequency of stools. Constipation is a common gastrointestinal disorder that can significantly impact quality of life.\n\nQuestion: What is the mechanism of action of Prucalopride in treating constipation?\n<start_of_turn>model\nPrucalopride, as a serotonin 5-HT4 receptor agonist, works by stimulating bowel movements and increasing the frequency of stools. This stimulation is achieved by activating these receptors in the gastrointestinal tract, which leads to increased peristalsis (muscle contractions that move food through the digestive system) and ultimately, more frequent and easier bowel movements. This mechanism is distinct from other treatments for constipation, which may involve different pathways or effects on the gastrointestinal system.',
#    'C': "<think>\nOkay, so I need to figure out the mechanism of action of prucalopride for treating constipation. Let me start by recalling what I know about prucalopride. It's a serotonin 5-HT4 receptor agonist. I remember that serotonin has various roles in the body, including in the gastrointestinal tract. \n\nFirst, I should think about the role of serotonin in the gut. I know that serotonin (5-HT) is involved in regulating gut motility. There are different types of serotonin receptors, and 5-HT4 is one of them. Agonists of 5-HT4 receptors are used for constipation, so I need to connect that.\n\nPrucalopride is used for chronic constipation. How does activating 5-HT4 receptors help with that? I think that in the gut, activating these receptors might increase peristalsis, which is the wave-like muscle contractions that move food through the digestive tract. If peristalsis is increased, that would help move stool along more effectively, reducing constipation.\n\nWait, but how exactly does the 5-HT4 receptor activation lead to increased peristalsis? Maybe it's through the enteric nervous system. The enteric nervous system controls the gastrointestinal tract, and serotonin receptors there are involved in signaling. When prucalopride binds to 5-HT4 receptors on the enteric neurons, it might stimulate the release of neurotransmitters like acetylcholine, which causes the smooth muscles in the gut to contract more forcefully or more frequently.\n\nAlso, there's something about the myenteric plexus, which is part of the enteric nervous system. The myenteric plexus is responsible for controlling the contractions of the gut. If prucalopride acts on the 5-HT4 receptors in the myenteric plexus, it could enhance the excitability of the neurons there, leading to increased peristaltic"},
#   'evaluations': {'C': {'context_fidelity': 8,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response A demonstrates a thorough understanding of the mechanism of action of prucalopride, correctly identifying its role as a serotonin 5-HT4 receptor agonist and its effects on gut motility. The response provides a detailed explanation of how prucalopride works, including its interaction with the enteric nervous system and the myenteric plexus. However, it does not directly quote the context and provides some speculative information about the exact mechanisms.'},
#    'B': {'context_fidelity': 9,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response B accurately describes the mechanism of action of prucalopride, correctly stating that it is a serotonin 5-HT4 receptor agonist that stimulates bowel movements and increases the frequency of stools. The response also provides additional information about the effects of prucalopride on peristalsis and the gastrointestinal tract, which is medically accurate. The response stays close to the provided context and avoids speculative or potentially dangerous information.'},
#    'A': {'context_fidelity': 10,
#     'medical_accuracy': 9,
#     'safety': 10,
#     'reasoning': 'Response C directly quotes the context and accurately describes the mechanism of action of prucalopride. The response correctly identifies prucalopride as a serotonin 5-HT4 receptor agonist and explains how it stimulates bowel movements and increases the frequency of stools. The response also provides a clear and concise explanation of how prucalopride achieves its effects, including the activation of receptors in the gut and the resulting increase in intestinal motility. The response is safe and stays close to the provided context.'}}}]
